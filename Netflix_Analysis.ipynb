# %% [markdown]
# # Netflix Content Analysis
#
# **Tools:** Python, Pandas, NumPy, Matplotlib
# **Dataset:** [Kaggle - Netflix Shows](https://www.kaggle.com/datasets/shivamb/netflix-shows)
# **Goal:** Explore Netflix content trends across countries,
# genres and ratings

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director']=df['director'].fillna('Unknown')

# %%
df['cast']=df['cast'].fillna('Unknown')

# %%
df['country']=df['country'].fillna('Unknown')

# %%
df['date_added']=df['date_added'].fillna('Unknown')

# %%
df['rating']=df['rating'].fillna(df['rating'].mode()[0])

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df['duration']=df['duration'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rename(columns={'listed_in':'genre'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rename(columns={'date_added':'date'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rename(columns={'release_year':'year'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rename(columns={'listed_in':'genre','date_added':'date','release_year':'year'},inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Uppercase all titles

# %%
df['title'].str.upper()
# Out:
# 0        DICK JOHNSON IS DEAD
# 1               BLOOD & WATER
# 2                   GANGLANDS
# 3       JAILBIRDS NEW ORLEANS
# 4                KOTA FACTORY
#                 ...
# 8802                   ZODIAC
# 8803              ZOMBIE DUMB
# 8804               ZOMBIELAND
# 8805                     ZOOM
# 8806                   ZUBAAN
# Name: title, Length: 8807, dtype: object

# %%
# Lowercase all type values

# %%
df['type'].str.lower()
# Out:
# 0         movie
# 1       tv show
# 2       tv show
# 3       tv show
# 4       tv show
#          ...
# 8802      movie
# 8803    tv show
# 8804      movie
# 8805      movie
# 8806      movie
# Name: type, Length: 8807, dtype: object

# %%
   # Find titles containing 'Love'

# %%
df[df['title'].str.contains('Love',case=False)]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                      Unknown
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                    Unknown
# 8575                    Unknown
# ...

# %%
# Find content from United States

# %%
df[df['country'].str.contains('United States',case =False)]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 7         s8    Movie               Sankofa     Haile Gerima
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People          Unknown
# 27       s28    Movie             Grown Ups     Dennis Dugan
# ...      ...      ...                   ...              ...
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8797   s8798  TV Show             Zak Storm          Unknown
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast  \
# 0                                               Unknown
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
# Length of each title

# %%
df['title'].str.len()
# Out:
# 0       20
# 1       13
# 2        9
# 3       21
# 4       12
#         ..
# 8802     6
# 8803    11
# 8804    10
# 8805     4
# 8806     6
# Name: title, Length: 8807, dtype: int64

# %%
# Replace 'TV Show' with 'Series'

# %%
df['type'] = df['type'].str.replace('TV Show','Series')

# %%
df
# Out:
#      show_id    type                  title         director  \
# 0         s1   Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  Series          Blood & Water          Unknown
# 2         s3  Series              Ganglands  Julien Leclercq
# 3         s4  Series  Jailbirds New Orleans          Unknown
# 4         s5  Series           Kota Factory          Unknown
# ...      ...     ...                    ...              ...
# 8802   s8803   Movie                 Zodiac    David Fincher
# 8803   s8804  Series            Zombie Dumb          Unknown
# 8804   s8805   Movie             Zombieland  Ruben Fleischer
# 8805   s8806   Movie                   Zoom     Peter Hewitt
# 8806   s8807   Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['is_movie']=df['type']=='Movie' # True if Movie, False if Series

# %%
df['title_length']=df['title'].str.len() ## Length of each title

# %%
df['long_movie']=df['duration'].apply(lambda x:'Yes'if '100' in str(x) else'No' ) ## Long movie or not

# %%
df
# Out:
#      show_id    type                  title         director  \
# 0         s1   Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  Series          Blood & Water          Unknown
# 2         s3  Series              Ganglands  Julien Leclercq
# 3         s4  Series  Jailbirds New Orleans          Unknown
# 4         s5  Series           Kota Factory          Unknown
# ...      ...     ...                    ...              ...
# 8802   s8803   Movie                 Zodiac    David Fincher
# 8803   s8804  Series            Zombie Dumb          Unknown
# 8804   s8805   Movie             Zombieland  Ruben Fleischer
# 8805   s8806   Movie                   Zoom     Peter Hewitt
# 8806   s8807   Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Movies vs TV Shows

# %%
df['type'].value_counts()
# Out:
# type
# Movie     6131
# Series    2676
# Name: count, dtype: int64

# %%
df[df['country'].str.contains('India',case =False)].count()
# Out:
# show_id         1046
# type            1046
# title           1046
# director        1046
# cast            1046
# country         1046
# date            1046
# year            1046
# rating          1046
# duration        1046
# genre           1046
# description     1046
# is_movie        1046
# title_length    1046
# long_movie      1046
# dtype: int64

# %%
df['country'].value_counts() # Titles per country
# Out:
# country
# United States                             2818
# India                                      972
# Unknown                                    831
# United Kingdom                             419
# Japan                                      245
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 749, dtype: int64

# %%
df['rating'].value_counts()   # Titles per rating
# Out:
# rating
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['genre'].value_counts() # Titles per genre
# Out:
# genre
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
df[df['type']=='Movie']  # show only movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[df['type']=='Series']  # Show only Series
# Out:
#      show_id    type                  title         director  \
# 1         s2  Series          Blood & Water          Unknown
# 2         s3  Series              Ganglands  Julien Leclercq
# 3         s4  Series  Jailbirds New Orleans          Unknown
# 4         s5  Series           Kota Factory          Unknown
# 5         s6  Series          Midnight Mass    Mike Flanagan
# ...      ...     ...                    ...              ...
# 8795   s8796  Series        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  Series             Yunus Emre          Unknown
# 8797   s8798  Series              Zak Storm          Unknown
# 8800   s8801  Series     Zindagi Gulzar Hai          Unknown
# 8803   s8804  Series            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               Unknown
# ...

# %%
# Show only content from India

# %%
df[df['country'].str.contains('India',case=False)]
# Out:
#      show_id    type                title                 director  \
# 4         s5  Series         Kota Factory                  Unknown
# 24       s25   Movie                Jeans               S. Shankar
# 29       s30   Movie             Paranoia           Robert Luketic
# 39       s40  Series         Chhota Bheem                  Unknown
# 50       s51  Series        Dharmakshetra                  Unknown
# ...      ...     ...                  ...                      ...
# 8773   s8774   Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  Series      Yeh Meri Family                  Unknown
# 8798   s8799   Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800   Movie                Zenda           Avadhoot Gupte
# 8806   s8807   Movie               Zubaan              Mozez Singh
#
#                                                    cast  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %%
# Show only content added after 2019

# %%
df[df['year']>2019]
# Out:
#      show_id    type                                      title  \
# 0         s1   Movie                       Dick Johnson Is Dead
# 1         s2  Series                              Blood & Water
# 2         s3  Series                                  Ganglands
# 3         s4  Series                      Jailbirds New Orleans
# 4         s5  Series                               Kota Factory
# ...      ...     ...                                        ...
# 7594   s7595   Movie         Norm of the North: Family Vacation
# 8099   s8100   Movie                                Straight Up
# 8125   s8126  Series                                Super Wings
# 8132   s8133  Series  Surviving R. Kelly Part II: The Reckoning
# 8437   s8438  Series                     The Netflix Afterparty
#
#              director                                               cast  \
# 0     Kirsten Johnson                                            Unknown
# ...

# %%
# Movies from United States with rating TV-MA

# %%
df[(df['country'].str.contains('United States',case = False)) & (df['type'] == 'Movie') & (df['rating']=='TV-MA')]
# Out:
#      show_id   type                                              title  \
# 7         s8  Movie                                            Sankofa
# 90       s91  Movie                                     Paradise Hills
# 96       s97  Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 101     s102  Movie                             Untold: Breaking Point
# 152     s153  Movie                      Janoskians: Untold and Untrue
# ...      ...    ...                                                ...
# 8716   s8717  Movie                                 Welcome to Willits
# 8734   s8735  Movie                          Who the F**k Is That Guy?
# 8738   s8739  Movie                                           Why Knot
# 8756   s8757  Movie                                          Woodstock
# 8760   s8761  Movie                                   Would You Rather
#
#                       director  \
# 7                 Haile Gerima
# 90            Alice Waddington
# ...

# %%
df.sort_values(by='year',ascending=False)
# Out:
#      show_id    type                                          title  \
# 693     s694   Movie                         Ali & Ratu Ratu Queens
# 781     s782   Movie          Black Holes | The Edge of All We Know
# 762     s763   Movie                                   Sweet & Sour
# 763     s764  Series                                    Sweet Tooth
# 764     s765   Movie                   Trippin' with the Kandasamys
# ...      ...     ...                                            ...
# 8660   s8661   Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764   Movie                WWII: Report from the Aleutians
# 8205   s8206   Movie                           The Battle of Midway
# 7790   s7791   Movie                                 Prelude to War
# 4250   s4251  Series              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# 693   Lucky Kuswandi  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...
# ...

# %%
df.sort_values(by='title')
# Out:
#      show_id    type                          title  \
# 2036   s2037   Movie                         #Alive
# 2304   s2305   Movie  #AnneFrank - Parallel Stories
# 2481   s2482   Movie              #FriendButMarried
# 2324   s2325   Movie            #FriendButMarried 2
# 5973   s5974   Movie                          #Roxy
# ...      ...     ...                            ...
# 6177   s6178  Series                       忍者ハットリくん
# 4914   s4915  Series                           海的儿子
# 7101   s7102  Series                           마녀사냥
# 5022   s5023   Movie                        반드시 잡는다
# 7108   s7109   Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# ...                           ...
# 6177                      Unknown
# 4914                      Unknown
# ...

# %%
df.sort_values(by='duration',ascending=False)
# Out:
#      show_id    type                                       title  \
# 5813   s5814   Movie        Louis C.K.: Live at the Comedy Store
# 5541   s5542   Movie                             Louis C.K. 2017
# 5794   s5795   Movie                       Louis C.K.: Hilarious
# 6915   s6916   Movie                                     Hangman
# 802     s803   Movie                              Ninja Assassin
# ...      ...     ...                                         ...
# 3474   s3475  Series                      The Liar and His Lover
# 3481   s3482  Series                               Bard of Blood
# 7017   s7018  Series  How to Live Mortgage Free with Sarah Beeny
# 3488   s3489  Series                                  The Inmate
# 4403   s4404  Series                              Medal of Honor
#
#             director                                               cast  \
# 5813      Louis C.K.                                         Louis C.K.
# ...

# %%
df.groupby('type')['title'].count()
# Out:
# type
# Movie     6131
# Series    2676
# Name: title, dtype: int64

# %%
##Count of titles per country

# %%
df.groupby('country')['title'].count()
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Name: title, Length: 749, dtype: int64

# %%
## Count of titles per rating

# %%
df.groupby('rating')['title'].count()
# Out:
# rating
# 66 min         1
# 74 min         1
# 84 min         1
# G             41
# NC-17          3
# NR            80
# PG           287
# PG-13        490
# R            799
# TV-14       2160
# TV-G         220
# TV-MA       3211
# TV-PG        863
# TV-Y         307
# TV-Y7        334
# TV-Y7-FV       6
# UR             3
# Name: title, dtype: int64

# %%
## Most common genre per country

# %%
df.groupby('country')['genre'].value_counts().fillna(0)
# Out:
# country            genre
# , France, Algeria  Dramas, Independent Movies, International Movies                     1
# , South Korea      International TV Shows, TV Dramas                                    1
# Argentina          Stand-Up Comedy                                                      8
#                    Crime TV Shows, International TV Shows, Spanish-Language TV Shows    6
#                    Dramas, International Movies                                         6
#                                                                                        ..
# Vietnam            Dramas, International Movies                                         1
#                    Dramas, International Movies, Romantic Movies                        1
#                    Horror Movies, International Movies, Thrillers                       1
# West Germany       Documentaries, International Movies                                  1
# ...

# %%
# Compare count of Movies vs TV Shows per rating

# %%
pd.pivot_table(df,values='title',index = 'rating',columns = 'type',aggfunc='count').fillna(0)
# Out:
# type       Movie  Series
# rating
# 66 min       1.0     0.0
# 74 min       1.0     0.0
# 84 min       1.0     0.0
# G           41.0     0.0
# NC-17        3.0     0.0
# NR          75.0     5.0
# PG         287.0     0.0
# PG-13      490.0     0.0
# R          797.0     2.0
# TV-14     1427.0   733.0
# TV-G       126.0    94.0
# TV-MA     2064.0  1147.0
# TV-PG      540.0   323.0
# TV-Y       131.0   176.0
# TV-Y7      139.0   195.0
# TV-Y7-FV     5.0     1.0
# UR           3.0     0.0

# %%
# Compare count of titles per country and type

# %%
pd.pivot_table(df,values='title',index='country',columns='type',aggfunc='count').fillna(0)
# Out:
# type                                                Movie  Series
# country
# , France, Algeria                                     1.0     0.0
# , South Korea                                         0.0     1.0
# Argentina                                            38.0    18.0
# Argentina, Brazil, France, Poland, Germany, Den...    1.0     0.0
# Argentina, Chile                                      2.0     0.0
# ...                                                   ...     ...
# Venezuela                                             1.0     0.0
# Venezuela, Colombia                                   1.0     0.0
# Vietnam                                               7.0     0.0
# West Germany                                          1.0     0.0
# Zimbabwe                                              1.0     0.0
#
# [749 rows x 2 columns]

# %%
df.to_csv('updated_netflix_data')
