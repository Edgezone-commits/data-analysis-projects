# %%
import pandas as pd            # Importing numpy panda and stat
import numpy as np  
import statistics

# %%
df = pd.read_csv('Housing.csv')

# %%
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0         4          2        3      yes        no
# 1    12250000  8960.0         4          4        4      yes        no
# 2    12250000  9960.0         3          2        2      yes        no
# 3    12215000  7500.0         4          2        2      yes        no
# 4    11410000  7420.0         4          1        2      yes       yes
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  3000.0         2          1        1      yes        no
# 541   1767150  2400.0         3          1        1       no        no
# 542   1750000     NaN         2          1        1      yes        no
# 543   1750000  2910.0         3          1        1       no        no
# 544   1750000  3850.0         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
mean  = statistics.mean(df.price)
mean
# Out:
# 4766729.247706422

# %%
# Using numpy
np.mean(df.price)
# Out:
# np.float64(4766729.247706422)

# %%
df.isna().sum()
# Out:
# price                0
# area                12
# bedrooms             0
# bathrooms            0
# stories              0
# mainroad             0
# guestroom            0
# basement             0
# hotwaterheating      0
# airconditioning      0
# parking              0
# prefarea             0
# furnishingstatus     3
# dtype: int64

# %%
mean = statistics.mean(df.area)

# %%
mean
# Out:
# nan

# %%
np.mean(df.area)
# Out:
# np.float64(5149.913696060037)

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
mean=statistics.mean(df.area)
mean
# Out:
# 5134.1584905660375

# %%
df['price'].skew()
# Out:
# np.float64(1.2555562245135674)

# %%
df['price'].kurtosis()
# Out:
# np.float64(2.232360487969864)

# %%
## T Test
from scipy.stats import ttest_1samp
import numpy as np
marks =[45,89,23,46,12,69,45,24,34,67]
mean = np.mean(marks)
mean
# Out:
# np.float64(45.4)

# %%
# Performing the T-Test
t_test,p_val = ttest_1samp(marks,30)
print ('p-value is:',p_val)
if p_val < 0.05:
    print('We can reject the null hypothesis')
else:
    print('We can accept the null hypothesis')
# Out:
# p-value is: 0.07179988272763561
# We can accept the null hypothesis

# %%
from scipy.stats import ttest_ind
import numpy as np
 
c1_marks = np.array([23,29,24,25,21,21,25,30,29,21,23,19,14,18,14,12,19,15])
c2_marks = np.array([23,22,25,21,26,21,21,25,30,24,21,23,19,14,18,14,12,19,15])
mean1=np.mean(c1_marks)
mean2=np.mean(c2_marks)
mean1,mean2

std1 = np.std(c1_marks)
std2 = np.std(c2_marks)
t_test,p_val=ttest_ind(c1_marks,c2_marks)
print('the P_Value is:',p_val)
if p_val < 0.05:
    print('We can reject the null hypothesis')
else:
    print('We can accept the null hypothesis')
# Out:
# the P_Value is: 0.7455407750299017
# We can accept the null hypothesis
