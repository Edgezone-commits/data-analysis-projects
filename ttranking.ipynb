# %% [markdown]
# # ITTF Table Tennis Player Analysis
#
# **Tools:** Python, Pandas, NumPy
# **Dataset:** [Kaggle - ITTF Players](https://www.kaggle.com/datasets/romanzdk/ittf-table-tennis-player-rankings-and-information)
# **Goal:** Analyze international table tennis player data
# — chose this dataset because I play table tennis competitively

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('ittf_player_info.csv')

# %%
df
# Out:
#        Player ID                Name Assoc  Gender  Birth year  Activity  \
# 0         113207       A'ASA Junella   ASA  Female      1976.0    Active
# 1         113276  A. QADER Bakhtiyar   IRQ    Male         NaN    Active
# 2         100002        AAA Shirchin   MGL    Male         NaN    Active
# 3         114572   AACHARYA Yashwant   IND    Male      1990.0  Inactive
# 4         112267      AAL ALI Faisal   UAE    Male      1991.0    Active
# ...          ...                 ...   ...     ...         ...       ...
# 37615     122986         ZOVKO Lovro   CRO    Male      2003.0    Active
# 37616     114031     ZOVKO Vjekoslav   CRO    Male      1993.0    Active
# 37617     116814  ZRAZHAVETS Mikalai   BLR    Male      1994.0    Active
# 37618     125506      ZRIMEC Tatjana   YUG  Female         NaN  Inactive
# 37619     121886      ZS.-SZABO Kira   HUN  Female      1998.0    Active
#
#        Playing hand Playing style       Grip
# 0                 -             -          -
# ...

# %%
df.head()
# Out:
#    Player ID                Name Assoc  Gender  Birth year  Activity  \
# 0     113207       A'ASA Junella   ASA  Female      1976.0    Active
# 1     113276  A. QADER Bakhtiyar   IRQ    Male         NaN    Active
# 2     100002        AAA Shirchin   MGL    Male         NaN    Active
# 3     114572   AACHARYA Yashwant   IND    Male      1990.0  Inactive
# 4     112267      AAL ALI Faisal   UAE    Male      1991.0    Active
#
#   Playing hand Playing style Grip
# 0            -             -    -
# 1          NaN           NaN  NaN
# 2          NaN           NaN  NaN
# 3          NaN           NaN  NaN
# 4          NaN           NaN  NaN

# %%
df.tail(107)
# Out:
#        Player ID                  Name Assoc  Gender  Birth year  Activity  \
# 37513     137569      ZHUBANOV Sanzhar   KAZ    Male      2003.0    Active
# 37514     115426  ZHUKOUSKAYA Lizaveta   BLR  Female      1993.0    Active
# 37515     123322        ZHUKOV Aleksei   RUS    Male      1989.0    Active
# 37516     120621          ZHUKOV Artem   RUS    Male      1995.0    Active
# 37517     113011             ZHUR Greg   USA    Male      1970.0    Active
# ...          ...                   ...   ...     ...         ...       ...
# 37615     122986           ZOVKO Lovro   CRO    Male      2003.0    Active
# 37616     114031       ZOVKO Vjekoslav   CRO    Male      1993.0    Active
# 37617     116814    ZRAZHAVETS Mikalai   BLR    Male      1994.0    Active
# 37618     125506        ZRIMEC Tatjana   YUG  Female         NaN  Inactive
# 37619     121886        ZS.-SZABO Kira   HUN  Female      1998.0    Active
#
#        Playing hand Playing style       Grip
# ...

# %%
df.shape
# Out:
# (37620, 9)

# %%
df.describe()
# Out:
#            Player ID    Birth year
# count   37620.000000  28184.000000
# mean   120369.414301   1975.867797
# std     12184.899853    179.584493
# min     90000.000000      0.000000
# 25%    109903.750000   1986.000000
# 50%    120576.500000   1995.000000
# 75%    130146.250000   2000.000000
# max    146262.000000   2014.000000

# %%
df.isna().sum()
# Out:
# Player ID            0
# Name                 0
# Assoc              109
# Gender               0
# Birth year        9436
# Activity           124
# Playing hand     28113
# Playing style    28113
# Grip             28113
# dtype: int64

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6120\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#        Player ID                Name Assoc  Gender  Birth year  Activity  \
# 0         113207       A'ASA Junella   ASA  Female      1976.0    Active
# 1         113276  A. QADER Bakhtiyar   IRQ    Male      1976.0    Active
# 2         100002        AAA Shirchin   MGL    Male      1976.0    Active
# 3         114572   AACHARYA Yashwant   IND    Male      1990.0  Inactive
# 4         112267      AAL ALI Faisal   UAE    Male      1991.0    Active
# ...          ...                 ...   ...     ...         ...       ...
# 37615     122986         ZOVKO Lovro   CRO    Male      2003.0    Active
# 37616     114031     ZOVKO Vjekoslav   CRO    Male      1993.0    Active
# 37617     116814  ZRAZHAVETS Mikalai   BLR    Male      1994.0    Active
# ...

# %%
df = df.dropna()

# %%
df.isna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9505 entries, 0 to 37619
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player ID      9505 non-null   bool
#  1   Name           9505 non-null   bool
#  2   Assoc          9505 non-null   bool
#  3   Gender         9505 non-null   bool
#  4   Birth year     9505 non-null   bool
#  5   Activity       9505 non-null   bool
#  6   Playing hand   9505 non-null   bool
#  7   Playing style  9505 non-null   bool
#  8   Grip           9505 non-null   bool
# dtypes: bool(9)
# memory usage: 157.8 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['Activity']=='Active']
# Out:
#        Player ID               Name Assoc  Gender  Birth year Activity  \
# 0         113207      A'ASA Junella   ASA  Female      1976.0   Active
# 5         145778  AALTONEN Gabriela   SWE  Female      2009.0   Active
# 12        145022      AARRAD Wahiba   MAR  Female      2003.0   Active
# 15        116168        AASEBO Anna   NOR  Female      1995.0   Active
# 16        110761       AASEBO Marte   NOR  Female      1990.0   Active
# ...          ...                ...   ...     ...         ...      ...
# 37613     137860       ZOUBEK Simon   CZE    Male      2008.0   Active
# 37614     137854     ZOUBKOVA Adela   CZE  Female      2006.0   Active
# 37615     122986        ZOVKO Lovro   CRO    Male      2003.0   Active
# 37616     114031    ZOVKO Vjekoslav   CRO    Male      1993.0   Active
# 37619     121886     ZS.-SZABO Kira   HUN  Female      1998.0   Active
#
#        Playing hand Playing style       Grip
# 0                 -             -          -
# ...

# %%
df[df['Gender']=='Female']
# Out:
#        Player ID               Name Assoc  Gender  Birth year Activity  \
# 0         113207      A'ASA Junella   ASA  Female      1976.0   Active
# 5         145778  AALTONEN Gabriela   SWE  Female      2009.0   Active
# 12        145022      AARRAD Wahiba   MAR  Female      2003.0   Active
# 15        116168        AASEBO Anna   NOR  Female      1995.0   Active
# 16        110761       AASEBO Marte   NOR  Female      1990.0   Active
# ...          ...                ...   ...     ...         ...      ...
# 37576     131741     ZOGHLAMI Maram   TUN  Female      2005.0   Active
# 37582     144234         ZOLEK Zoja   SLO  Female      2007.0   Active
# 37596     115179      ZONJIC Dijana   MNE  Female      1960.0   Active
# 37614     137854     ZOUBKOVA Adela   CZE  Female      2006.0   Active
# 37619     121886     ZS.-SZABO Kira   HUN  Female      1998.0   Active
#
#        Playing hand Playing style       Grip
# 0                 -             -          -
# ...

# %%
df[df['Playing hand']=='Left-handed']
# Out:
#        Player ID                Name Assoc  Gender  Birth year Activity  \
# 32        137295      ABASSIA Cherif   TUN    Male      2006.0   Active
# 86        116723  ABDEL-AZIZ Youssef   EGY    Male      2000.0   Active
# 95        122183      ABDELAAL Adham   EGY    Male      2001.0   Active
# 99        133560    ABDELAZIZ Mariam   EGY  Female      2001.0   Active
# 113       137393    ABDELHASAN Ahmed   IRQ    Male      1987.0   Active
# ...          ...                 ...   ...     ...         ...      ...
# 37553     131225  ZIRONOVA Ekaterina   RUS  Female      2002.0   Active
# 37565     135401        ZLATKOV Luka   CRO    Male      2005.0   Active
# 37579     136730         ZOHIL Borna   CRO    Male      2006.0   Active
# 37605     137545       ZOU Hangcheng   CHN    Male      1999.0   Active
# 37609     136627     ZOU Shang-Cheng   TPE    Male      2003.0   Active
#
#       Playing hand Playing style       Grip
# 32     Left-handed      Attacker  Shakehand
# ...

# %%
df[(df['Activity']=='Active') & (df['Gender']=='Male') & (df['Playing style']=='Attacker')]
# Out:
#        Player ID                      Name Assoc Gender  Birth year Activity  \
# 20        136164  ABADLI Wafi Chams Eddine   ALG   Male      2007.0   Active
# 32        137295            ABASSIA Cherif   TUN   Male      2006.0   Active
# 42        137325              ABBAS Fadhel   BRN   Male      2004.0   Active
# 68        144666            ABDALLA Yousif   QAT   Male      2009.0   Active
# 86        116723        ABDEL-AZIZ Youssef   EGY   Male      2000.0   Active
# ...          ...                       ...   ...    ...         ...      ...
# 37605     137545             ZOU Hangcheng   CHN   Male      1999.0   Active
# 37609     136627           ZOU Shang-Cheng   TPE   Male      2003.0   Active
# 37613     137860              ZOUBEK Simon   CZE   Male      2008.0   Active
# 37615     122986               ZOVKO Lovro   CRO   Male      2003.0   Active
# 37616     114031           ZOVKO Vjekoslav   CRO   Male      1993.0   Active
#
#        Playing hand Playing style       Grip
# ...

# %%
df[df['Birth year'] > 2000]
# Out:
#        Player ID                      Name Assoc  Gender  Birth year Activity  \
# 5         145778         AALTONEN Gabriela   SWE  Female      2009.0   Active
# 12        145022             AARRAD Wahiba   MAR  Female      2003.0   Active
# 20        136164  ABADLI Wafi Chams Eddine   ALG    Male      2007.0   Active
# 24        135207        ABARAVICIUTE Laura   LTU  Female      2004.0   Active
# 32        137295            ABASSIA Cherif   TUN    Male      2006.0   Active
# ...          ...                       ...   ...     ...         ...      ...
# 37582     144234                ZOLEK Zoja   SLO  Female      2007.0   Active
# 37609     136627           ZOU Shang-Cheng   TPE    Male      2003.0   Active
# 37613     137860              ZOUBEK Simon   CZE    Male      2008.0   Active
# 37614     137854            ZOUBKOVA Adela   CZE  Female      2006.0   Active
# 37615     122986               ZOVKO Lovro   CRO    Male      2003.0   Active
#
# ...

# %%
df.sort_values(by='Birth year',ascending=False)
# Out:
#        Player ID                    Name Assoc  Gender  Birth year Activity  \
# 15453     145970        KANZA Kuka Joyce   COD    Male      2014.0   Active
# 28867     146172             SAIDI Ahmed   TUN    Male      2012.0   Active
# 17492     145971      KUMANAE Wembo Radi   COD    Male      2012.0   Active
# 17942     145981   LANDU Mbenza Djanella   COD  Female      2012.0   Active
# 1873      145978  ANGELANI Nsumbu Davina   COD  Female      2012.0   Active
# ...          ...                     ...   ...     ...         ...      ...
# 4773      137040   BUZAROVSKI Metodij ^^   MKD    Male         0.0   Active
# 34567     125893           VENTURA Byron   GUA    Male         0.0   Active
# 36803     125561            YQUEL Rozenn   FRA  Female         0.0   Active
# 9598      145377  FERNANDEZ Vianelkis ^^   DOM  Female         0.0   Active
# 34485     136704   VECCHIATO Riccardo ^^   ITA    Male         0.0   Active
#
#        Playing hand Playing style       Grip
# ...

# %%
df.sort_values(by='Assoc')
# Out:
#        Player ID                         Name Assoc  Gender  Birth year  \
# 151       135114  ABDUL SAMI Khan Mohammad ^^   AFG    Male      1977.0
# 1646      100521         AMIN MOHD Najibullah   AFG    Male      1990.0
# 23335     145474             NAJAFI Nooria ^^   AFG  Female      1996.0
# 8881      145475             ELYASSI Marwa ^^   AFG  Female      1995.0
# 13314     145467         HOSSEINI Mohammad ^^   AFG    Male      1984.0
# ...          ...                          ...   ...     ...         ...
# 1088      123614                 ALAEBANI Ali   YEM    Male      2000.0
# 964       131392          AL-MAHAQERI Mahmood   YEM    Male      2003.0
# 875       123615              AL-DHAMARI Taha   YEM    Male      2001.0
# 28733     112817                   SABRI Loai   YEM  Female         0.0
# 12137     124065            HAMALAMBO Choolwe   ZAM    Male      1998.0
#
#       Activity  Playing hand Playing style       Grip
# ...

# %%
df.groupby('Assoc')['Player ID'].count()
# Out:
# Assoc
# AFG     5
# ALB     4
# ALG    68
# ANG    15
# ARG    93
#        ..
# VIN     9
# WAL    33
# WLF     5
# YEM     7
# ZAM     1
# Name: Player ID, Length: 186, dtype: int64

# %%
df.groupby('Activity')['Player ID'].count()
# Out:
# Activity
# Active      8987
# Inactive     518
# Name: Player ID, dtype: int64

# %%
df.groupby('Gender')['Birth year'].mean()
# Out:
# Gender
# Female    1967.868468
# Male      1938.365102
# Name: Birth year, dtype: float64

# %%
df.groupby(['Gender','Playing style'])['Player ID'].count()
# Out:
# Gender  Playing style
# Female  -                 606
#         Attacker         3076
#         Defender          241
# Male    -                 975
#         Attacker         4423
#         Defender          184
# Name: Player ID, dtype: int64

# %%
pd.pivot_table(df,values='Player ID',index='Gender',columns='Playing style',aggfunc='count')
# Out:
# Playing style    -  Attacker  Defender
# Gender
# Female         606      3076       241
# Male           975      4423       184

# %%
df
# Out:
#        Player ID               Name Assoc  Gender  Birth year  Activity  \
# 0         113207      A'ASA Junella   ASA  Female      1976.0    Active
# 5         145778  AALTONEN Gabriela   SWE  Female      2009.0    Active
# 10        110737          AARAS Pal   NOR    Male      1992.0  Inactive
# 12        145022      AARRAD Wahiba   MAR  Female      2003.0    Active
# 15        116168        AASEBO Anna   NOR  Female      1995.0    Active
# ...          ...                ...   ...     ...         ...       ...
# 37613     137860       ZOUBEK Simon   CZE    Male      2008.0    Active
# 37614     137854     ZOUBKOVA Adela   CZE  Female      2006.0    Active
# 37615     122986        ZOVKO Lovro   CRO    Male      2003.0    Active
# 37616     114031    ZOVKO Vjekoslav   CRO    Male      1993.0    Active
# 37619     121886     ZS.-SZABO Kira   HUN  Female      1998.0    Active
#
#        Playing hand Playing style       Grip
# 0                 -             -          -
# ...

# %%
df.rename(columns={'Player ID':'player_id','Birth year':'birth_year','Playing hand':'playing_hand','Playing style':'playing_style'},inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6120\3457439583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Player ID':'player_id','Birth year':'birth_year','Playing hand':'playing_hand','Playing style':'playing_style'},inplace=True)

# %%
df
# Out:
#        player_id               Name Assoc  Gender  birth_year  Activity  \
# 0         113207      A'ASA Junella   ASA  Female      1976.0    Active
# 5         145778  AALTONEN Gabriela   SWE  Female      2009.0    Active
# 10        110737          AARAS Pal   NOR    Male      1992.0  Inactive
# 12        145022      AARRAD Wahiba   MAR  Female      2003.0    Active
# 15        116168        AASEBO Anna   NOR  Female      1995.0    Active
# ...          ...                ...   ...     ...         ...       ...
# 37613     137860       ZOUBEK Simon   CZE    Male      2008.0    Active
# 37614     137854     ZOUBKOVA Adela   CZE  Female      2006.0    Active
# 37615     122986        ZOVKO Lovro   CRO    Male      2003.0    Active
# 37616     114031    ZOVKO Vjekoslav   CRO    Male      1993.0    Active
# 37619     121886     ZS.-SZABO Kira   HUN  Female      1998.0    Active
#
#        playing_hand playing_style       Grip
# 0                 -             -          -
# ...

# %%
df.groupby('playing_style')['Name'].count()
# Out:
# playing_style
# -           1581
# Attacker    7499
# Defender     425
# Name: Name, dtype: int64
